# %% [markdown]
# <img src='images/plotly-logo-01-stripe@2x.png' width=30%>
#
#
# ***<font color="grey">Interactive Data Visualization Using Python</font>***
#
# Code accompanying slides at [slides.com ](http://slides.com/chumo/plotly)
#
# >Jesús Martínez Blanco
# ><font color="red">Data Scientist, LiveIntent Inc.</font>

# %%
# Import the library
import plotly as py

# %%
# and enable the offline mode in the notebook (not needed in Jupyter Lab)
py.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Building blocks of Plotly plots
import plotly.graph_objs as go

# %%
# Constructing a figure
import numpy as np
x = np.linspace(0, 2*np.pi)

# Traces
trace0 = go.Scatter(x=x, y=np.sin(x))
trace1 = go.Scatter(x=x, y=np.cos(x))

# Figure
fig = go.Figure(data=[trace0, trace1])

# %%
# and now with a Layout
x = np.linspace(0, 2*np.pi)

# Traces
trace0 = go.Scatter(x=x, y=np.sin(x), name='sin(x)')
trace1 = go.Scatter(x=x, y=np.cos(x), name='cos(x)')

# Layout
layout = go.Layout(title='SIN and COS functions',
                   xaxis=dict(title='x'),
                   yaxis=dict(title='f(x)'))

# Figure
fig = go.Figure(data=[trace0, trace1], layout=layout)

# %%
# Display the result within the notebook:
py.offline.iplot(fig)
# Out:
# <div id="9cda7e4a-8654-4280-8045-7055deb8d4c2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9cda7e4a-8654-4280-8045-7055deb8d4c2", [{"type": "scatter", "x": [0.0, 0.1282282715750936, 0.2564565431501872, 0.38468481472528077, 0.5129130863003744, 0.6411413578754679, 0.7693696294505615, 0.8975979010256552, 1.0258261726007487, 1.1540544441758422, 1.2822827157509358, 1.4105109873260295, 1.538739258901123, 1.6669675304762166, 1.7951958020513104, 1.9234240736264039, 2.0516523452014974, 2.179880616776591, 2.3081088883516845, 2.436337159926778, 2.5645654315018716, 2.6927937030769655, 2.821021974652059, 2.9492502462271526, 3.077478517802246, 3.2057067893773397, 3.333935060952433, 3.4621633325275267, 3.5903916041026207, 3.7186198756777142, 3.8468481472528078, 3.9750764188279013, 4.103304690402995, 4.231532961978089, 4.359761233553182, 4.487989505128276, 4.616217776703369, 4.744446048278463, 4.872674319853556, 5.00090259142865, 5.129130863003743, 5.257359134578837, 5.385587406153931, 5.513815677729024, 5.642043949304118, 5.770272220879211, 5.898500492454305, 6.026728764029398, 6.154957035604492, 6.283185307179586], "y": [0.0, 0.127877161684506, 0.25365458390950735, 0.3752670048793741, 0.49071755200393785, 0.5981105304912159, 0.6956825506034864, 0.7818314824680298, 0.8551427630053461, 0.9144126230158124, 0.9586678530366606, 0.9871817834144502, 0.9994862162006879, 0.9953791129491982, 0.9749279121818236, 0.9384684220497604, 0.8865993063730001, 0.8201722545969561, 0.7402779970753157, 0.6482283953077888, 0.545534901210549, 0.43388373911755823, 0.3151082180236209, 0.19115862870137254, 0.06407021998071323, -0.06407021998071255, -0.19115862870137187, -0.3151082180236202, -0.433883739117558, -0.5455349012105485, -0.6482283953077882, -0.7402779970753153, -0.8201722545969556, -0.886599306373, -0.9384684220497602, -0.9749279121818236, -0.9953791129491981, -0.9994862162006879, -0.9871817834144503, -0.9586678530366608, -0.9144126230158128, -0.8551427630053464, -0.7818314824680299, -0.6956825506034
, 0.49071755200393785, 0.5981105304912159, 0.6956825506034864, 0.7818314824680298, 0.8551427630053461, 0.9144126230158124, 0.9586678530366606, 0.9871817834144502, 0.9994862162006879, 0.9953791129491982, 0.9749279121818236, 0.9384684220497604, 0.8865993063730001, 0.8201722545969561, 0.7402779970753157, 0.6482283953077888, 0.545534901210549, 0.43388373911755823, 0.3151082180236209, 0.19115862870137254, 0.06407021998071323, -0.06407021998071255, -0.19115862870137187, -0.3151082180236202, -0.433883739117558, -0.5455349012105485, -0.6482283953077882, -0.7402779970753153, -0.8201722545969556, -0.886599306373, -0.9384684220497602, -0.9749279121818236, -0.9953791129491981, -0.9994862162006879, -0.9871817834144503, -0.9586678530366608, -0.9144126230158128, -0.8551427630053464, -0.7818314824680299, -0.6956825506034869, -0.5981105304912162, -0.49071755200393863, -0.3752670048793746, -0.25365458390950835, -0.12787716168450664, -2.4492935982947064e-16], "name": "sin(x)"}, {"type": "scatter", "x": [0.0, 0.1282282715750936, 0.2564565431501872, 0.38468481472528077, 0.5129130863003744, 0.6411413578754679, 0.7693696294505615, 0.8975979010256552, 1.0258261726007487, 1.1540544441758422, 1.2822827157509358, 1.4105109873260295, 1.538739258901123, 1.6669675304762166, 1.7951958020513104, 1.9234240736264039, 2.0516523452014974, 2.179880616776591, 2.3081088883516845, 2.436337159926778, 2.5645654315018716, 2.6927937030769655, 2.821021974652059, 2.9492502462271526, 3.077478517802246, 3.2057067893773397, 3.333935060952433, 3.4621633325275267, 3.5903916041026207, 3.7186198756777142, 3.8468481472528078, 3.9750764188279013, 4.103304690402995, 4.231532961978089, 4.359761233553182, 4.487989505128276, 4.616217776703369, 4.744446048278463, 4.872674319853556, 5.00090259142865, 5.129130863003743, 5.257359134578837, 5.385587406153931, 5.513815677729024, 5.642043949304118, 5.770272220879211, 5.898500492454305, 6.026728764029398, 6.154957035604492, 6.283185307179586], "y": [1.0, 0.9917900138232462, 0.9672948630390295, 0.9269167573460217, 0.8713187041233894, 0.8014136218679567, 0.7183493500977276, 0.6234898018587336, 0.5183925683105252, 0.404783343122394, 0.28452758663103267, 0.15959989503337932, 0.03205157757165533, -0.09602302590768154, -0.22252093395631434, -0.3453650544213075, -0.4625382902408351, -0.5721166601221694, -0.6723008902613166, -0.7614459583691342, -0.8380881048918404, -0.900968867902419, -0.9490557470106686, -0.9815591569910653, -0.9979453927503363, -0.9979453927503363, -0.9815591569910654, -0.9490557470106689, -0.9009688679024191, -0.8380881048918408, -0.7614459583691346, -0.672300890261317, -0.57 ...

# %%
# Export it as static image
#py.plotly.image.save_as(fig, filename='sin_cos.png')

# %%
# Create a stand-alone html file 
py.offline.plot(fig, filename='sin_cos.html')
# Out:
# 'file:///home/batman/git/ref_DataScienceRetreat/DSR Lecture notebooks/Module X - Visualization/sin_cos.html'

# %%
# or just a <div> element with the plot to embed in your web page
div_str = py.offline.plot(fig, output_type='div', include_plotlyjs=False)

# %%
with open('sin_cos_as_div.html', 'w') as f:
    f.write(div_str)

# %%
# To share it via the Plotly cloud, a Plotly account is necessary (possible for free)
# and the credentials should be configured:
import os
PLOTLY_API_KEY = os.environ.get('PLOTLY_API_KEY')
py.tools.set_credentials_file(username='jmb.jesus', api_key=PLOTLY_API_KEY)

# %%
# Share it via the Plotly cloud
#py.plotly.plot(fig, filename='sin_cos', sharing='public')

# %% [markdown]
# ### Cufflinks

# %%
import cufflinks as cf

# Configure it to work offline:
cf.go_offline(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# A random dataframe as example
import pandas as pd

df = pd.DataFrame({'Column A':[2,5,3,4,1],
                   'Column B':[6,2,4,1,8]})

# %%
# Set layout assets individually
df.iplot(kind='bar', title='An example', xTitle='index', yTitle='value')
# Out:
# <div id="fa005e43-6ed3-4767-8d23-5445dc7535e7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fa005e43-6ed3-4767-8d23-5445dc7535e7", [{"type": "bar", "x": [0, 1, 2, 3, 4], "y": [2, 5, 3, 4, 1], "name": "Column A", "text": "", "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "orientation": "v"}, {"type": "bar", "x": [0, 1, 2, 3, 4], "y": [6, 2, 4, 1, 8], "name": "Column B", "text": "", "marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "orientation": "v"}], {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "yaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "showgrid": true, "title": "value"}, "xaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "showgrid": true, "title": "index"}, "titlefont": {"color": "#4D5663"}, "title": "An example"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Set layout as a whole:
layout = dict(title='An example',
              xaxis=dict(title='index'),
              yaxis=dict(title='value'))

df.iplot(kind='bar', 
         layout=layout)
# Out:
# <div id="27c3023a-fbe2-47f2-b4cc-b6530194ff7e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("27c3023a-fbe2-47f2-b4cc-b6530194ff7e", [{"type": "bar", "x": [0, 1, 2, 3, 4], "y": [2, 5, 3, 4, 1], "name": "Column A", "text": "", "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "orientation": "v"}, {"type": "bar", "x": [0, 1, 2, 3, 4], "y": [6, 2, 4, 1, 8], "name": "Column B", "text": "", "marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "orientation": "v"}], {"title": "An example", "xaxis": {"title": "index"}, "yaxis": {"title": "value"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
fig = df.iplot(kind='bar',
               layout=layout, 
               asFigure=True)

#py.plotly.plot(fig, filename='cufflinks_example', sharing='public')
py.plotly.plot(fig, filename='cufflinks_example', sharing='public')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-19-c80ff9be483d> in <module>()
#       4
#       5 #py.plotly.plot(fig, filename='cufflinks_example', sharing='public')
# ----> 6 py.plotly.plot(fig, filename='cufflinks_example', sharing='public')
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
#     235     # Check if the url needs a secret key
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Aw, snap! You tried to use our API as the user 'jmb.jesus', but the supplied API key doesn't match our records. You can view your API key at plot.ly/settings.
#
# You're most likely getting this message because your local credentials file isn't synced with the Plotly server you're communicating with.
#
# Go to plot.ly/<language>/getting-started (e.g., plot.ly/python/getting-started) for more information.
#
# Make sure that you're logged in as jmb.jesus.
#
# Need help? Please try searching Plotly's <a href='http://stackoverflow.com/questions/tagged/plotly'>Stack Overflow channel</a>.

# %%
# Use asFigure=True to return a Plotly figure...
fig = df.iplot(kind='bar',
               layout=layout,
               asFigure=True)

# ... that can be manipulated as such:
div_str = py.offline.plot(fig,
                          output_type='div',
                          include_plotlyjs=False)
