# %% [markdown]
# # Linear Perceptron
#
# In this notebook you'll call into the implemented `Perceptron` class to fit a linear classifier.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import perceptron
import sample_perceptron

print(np.__version__)
# Out:
# 1.13.1

# %%
def plot_decision_boundary(w, b, xx):
    # solve w_x * x + w_y*y + b = 0, for y
    yy = (-b - w[0]*xx)/w[1]
    plt.plot(xx, yy, 'k--')

# %%
np.random.seed(42)
N = 1000
X = np.concatenate(([5, 6] + np.random.randn(N, 2), [-1, -1] + np.random.randn(N, 2)))
y = np.concatenate((np.ones(N), -np.ones(N)))

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[y == -1,0], X[y == -1,1], color='r', alpha=1)
plt.scatter(X[y == 1,0], X[y == 1,1], color='b', alpha=1)

for _ in range(30):
    p = sample_perceptron.Perceptron()
    p.fit(X, y)
    plot_decision_boundary(p.theta[0:2], p.theta[-1], np.linspace(-10, 10))
    
    intercept = np.ones((X.shape[0], 1))
    XX = np.concatenate((X, intercept), axis=1)
    perceptron_accuracy = 100.0*np.sum([np.sign(np.dot(p.theta.T, x)) == yy for x, yy in zip(XX, y)])/X.shape[0]
    assert(perceptron_accuracy == 100.0)

plt.xlim([-5.0, 10])
plt.ylim([-5, 11])
plt.grid()

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[y == -1,0], X[y == -1,1], color='r', alpha=1)
plt.scatter(X[y == 1,0], X[y == 1,1], color='b', alpha=1)

for _ in range(30):
    p = perceptron.Perceptron()
    p.fit(X, y)
    plot_decision_boundary(p.theta[0:2], p.theta[-1], np.linspace(-10, 10))
    
    intercept = np.ones((X.shape[0], 1))
    XX = np.concatenate((X, intercept), axis=1)
    perceptron_accuracy = 100.0*np.sum([np.sign(np.dot(p.theta.T, x)) == yy for x, yy in zip(XX, y)])/X.shape[0]
    assert(perceptron_accuracy == 100.0)

plt.xlim([-5.0, 10])
plt.ylim([-5, 11])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-27-fc56e6a32266> in <module>()
#       5 for _ in range(30):
#       6     p = perceptron.Perceptron()
# ----> 7     p.fit(X, y)
#       8     plot_decision_boundary(p.theta[0:2], p.theta[-1], np.linspace(-10, 10))
#       9
#
# C:\Users\jon\git\data-science-retreat-svm\01_perceptron\perceptron.py in fit(self, X, y)
#      17         intercept = np.ones((X.shape[0], 1))
#      18         X = np.concatenate((X, intercept), axis=1)
# ---> 19         raise NotImplementedError
#
# NotImplementedError:
