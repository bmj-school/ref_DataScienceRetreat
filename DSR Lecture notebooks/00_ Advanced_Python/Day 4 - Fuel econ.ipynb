# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sqlite3
import os, os.path
os.getcwd()
# Out:
# 'C:\\Users\\jon\\git\\ref_DataScienceRetreat\\DSR Lecture notebooks\\00_ Advanced_Python'

# %%
vehicles = pd.read_csv("http://www.gagolewski.com/resources/data/fueleconomy_vehicles.csv.gz",
                     comment="#")

# %%
vehicles.head()
# Out:
#       id        make                model  year                        class  \
# 0  27550  AM General    DJ Po Vehicle 2WD  1984  Special Purpose Vehicle 2WD
# 1  28426  AM General    DJ Po Vehicle 2WD  1984  Special Purpose Vehicle 2WD
# 2  27549  AM General     FJ8c Post Office  1984  Special Purpose Vehicle 2WD
# 3  28425  AM General     FJ8c Post Office  1984  Special Purpose Vehicle 2WD
# 4   1032  AM General  Post Office DJ5 2WD  1985  Special Purpose Vehicle 2WD
#
#              trans             drive  cyl  displ     fuel  hwy  cty
# 0  Automatic 3-spd     2-Wheel Drive  4.0    2.5  Regular   17   18
# 1  Automatic 3-spd     2-Wheel Drive  4.0    2.5  Regular   17   18
# 2  Automatic 3-spd     2-Wheel Drive  6.0    4.2  Regular   13   13
# 3  Automatic 3-spd     2-Wheel Drive  6.0    4.2  Regular   13   13
# 4  Automatic 3-spd  Rear-Wheel Drive  4.0    2.5  Regular   17   16

# %%
vehicles.describe()
# Out:
#                  id          year           cyl         displ           hwy  \
# count  33442.000000  33442.000000  33384.000000  33385.000000  33442.000000
# mean   17038.299743   1999.107709      5.771867      3.352557     23.551283
# std    10087.007470      9.377047      1.740931      1.359846      6.211417
# min        1.000000   1984.000000      2.000000      0.000000      9.000000
# 25%     8361.250000   1991.000000      4.000000      2.300000     19.000000
# 50%    16723.500000   1999.000000      6.000000      3.000000     23.000000
# 75%    25264.750000   2008.000000      6.000000      4.300000     27.000000
# max    34932.000000   2015.000000     16.000000      8.400000    109.000000
#
#                 cty
# count  33442.000000
# mean      17.490999
# std        5.582174
# min        6.000000
# 25%       15.000000
# 50%       17.000000
# 75%       20.000000
# max      138.000000

# %%
def convert_mileage(m):
    return (236.5 / m )

# %%
vehicles['hwySI'] = vehicles.loc[:,['hwy']].apply(convert_mileage,axis=0)
vehicles['ctySI'] = vehicles.loc[:,['cty']].apply(convert_mileage,axis=0)
veh2 = vehicles
#vehicles['hwySI','ctySI'] = vehicles.loc[:,['hwy','cty']].apply(convert_mileage,axis=0)

# %%
veh2.head()
# Out:
#       id        make                model  year                        class  \
# 0  27550  AM General    DJ Po Vehicle 2WD  1984  Special Purpose Vehicle 2WD
# 1  28426  AM General    DJ Po Vehicle 2WD  1984  Special Purpose Vehicle 2WD
# 2  27549  AM General     FJ8c Post Office  1984  Special Purpose Vehicle 2WD
# 3  28425  AM General     FJ8c Post Office  1984  Special Purpose Vehicle 2WD
# 4   1032  AM General  Post Office DJ5 2WD  1985  Special Purpose Vehicle 2WD
#
#              trans             drive  cyl  displ     fuel  hwy  cty  \
# 0  Automatic 3-spd     2-Wheel Drive  4.0    2.5  Regular   17   18
# 1  Automatic 3-spd     2-Wheel Drive  4.0    2.5  Regular   17   18
# 2  Automatic 3-spd     2-Wheel Drive  6.0    4.2  Regular   13   13
# 3  Automatic 3-spd     2-Wheel Drive  6.0    4.2  Regular   13   13
# 4  Automatic 3-spd  Rear-Wheel Drive  4.0    2.5  Regular   17   16
#
#        hwySI      ctySI      hwyZ      ctyZ
# 0  13.911765  13.138889  1.166941 -0.365275
# ...

# %%
#veh2['hwyZ'] = (veh2['hwySI'] - veh2['hwySI'].mean())/veh2['hwySI'].std(ddof=0)
#veh2['ctyZ'] = (veh2['ctySI'] - veh2['ctySI'].mean())/veh2['ctySI'].std(ddof=0)

# %%
#def my_Z(series):
#    mean = series.mean()
    
zscore = lambda x: (x - x.mean()) / x.std()

# %%
#veh2.groupby('class').agg()

# %%
veh2['hwyZ'] = veh2.groupby('class')['hwySI'].transform(zscore)
veh2['ctyZ'] = veh2.groupby('class')['ctySI'].transform(zscore)
veh2.head(10)
#len(veh2)
# Out:
#       id              make                model  year  \
# 0  27550        AM General    DJ Po Vehicle 2WD  1984
# 1  28426        AM General    DJ Po Vehicle 2WD  1984
# 2  27549        AM General     FJ8c Post Office  1984
# 3  28425        AM General     FJ8c Post Office  1984
# 4   1032        AM General  Post Office DJ5 2WD  1985
# 5   1033        AM General  Post Office DJ8 2WD  1985
# 6   3347  ASC Incorporated                  GNX  1987
# 7  13309             Acura          2.2CL/3.0CL  1997
# 8  13310             Acura          2.2CL/3.0CL  1997
# 9  13311             Acura          2.2CL/3.0CL  1997
#
#                          class            trans              drive  cyl  \
# 0  Special Purpose Vehicle 2WD  Automatic 3-spd      2-Wheel Drive  4.0
# 1  Special Purpose Vehicle 2WD  Automatic 3-spd      2-Wheel Drive  4.0
# 2  Special Purpose Vehicle 2WD  Automatic 3-spd      2-Wheel Drive  6.0
# 3  Special Purpose Vehicle 2WD  Automatic 3-spd      2-Wheel Drive  6.0
# ...

# %%
#veh2.groupby('class').mean()

# %%
w = pd.read_csv("http://www.gagolewski.com/resources/data/warsaw_weather.csv",
                     comment="#")
#w.head(10)
w
#len(w)
# Out:
#     Unnamed: 0                                                  0  \
# 0            0  Climate data for Warsaw (1981–2010) Extremes (...
# 1            1                                              Month
# 2            2                                Record high °C (°F)
# 3            3                               Average high °C (°F)
# 4            4                                 Daily mean °C (°F)
# 5            5                                Average low °C (°F)
# 6            6                                 Record low °C (°F)
# 7            7                  Average precipitation mm (inches)
# 8            8                         Average precipitation days
# 9            9                                            Source
# 10          10                                            Source
#
#                 1              2             3            4            5  \
# 0             NaN            NaN           NaN          NaN          NaN
# ...

# %%
w.drop(['0','Unnamed: 0'],axis=0)
#w.drop('0',axis =1)
#w = w.transpose()
#w
# Out:
#      0     1            2            3            4            5   \
# 1   NaN   Jan  13.8 (56.8)   0.6 (33.1)  −1.8 (28.8)  −4.2 (24.4)
# 2   NaN   Feb    17.2 (63)   1.9 (35.4)  −0.6 (30.9)  −3.6 (25.5)
# 3   NaN   Mar  22.9 (73.2)   6.6 (43.9)     2.8 (37)  −0.6 (30.9)
# 4   NaN   Apr  30.5 (86.9)  13.6 (56.5)   8.7 (47.7)     3.9 (39)
# 5   NaN   May    32.8 (91)  19.5 (67.1)  14.2 (57.6)     8.9 (48)
# 6   NaN   Jun  35.1 (95.2)  21.9 (71.4)  17.0 (62.6)  11.8 (53.2)
# 7   NaN   Jul  36.0 (96.8)  24.4 (75.9)  19.2 (66.6)    13.9 (57)
# 8   NaN   Aug  37.1 (98.8)    23.9 (75)  18.3 (64.9)  13.1 (55.6)
# 9   NaN   Sep  34.5 (94.1)  18.4 (65.1)  13.5 (56.3)   9.1 (48.4)
# 10  NaN   Oct  25.9 (78.6)  12.7 (54.9)   8.5 (47.3)   4.8 (40.6)
# 11  NaN   Nov    18.9 (66)   5.9 (42.6)   3.3 (37.9)   0.6 (33.1)
# 12  NaN   Dec  15.4 (59.7)   1.6 (34.9)  −0.7 (30.7)  −3.0 (26.6)
# 13  NaN  Year  37.1 (98.8)  12.6 (54.7)   8.5 (47.3)   4.6 (40.3)
#
# ...
