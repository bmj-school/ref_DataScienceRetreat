# %% [markdown]
# # NUMERAPI
# upload predictions easily from cloud

# %% [markdown]
# generate API keys to interact with Numerai services
# go to numer.ai-->account-->settings-->custom api keys

# %%
from numerapi.numerapi import NumerAPI
sk="GBRUEZBUPNHPRVPEV7NEGL4YMY4GNFHW5VCD4VYR5MVCXLKWFLRVT7OSZTUDXA77"
pk="ZCXFJHPVWEFTHDUE3DPF6PQKWM5CK7RN"

# %%
napi = NumerAPI(public_id=pk,secret_key=sk)

# %%
napi.upload_predictions("predictions.csv")
# Out:
# 2018-03-24 15:40:25,534 INFO numerapi.numerapi: uploading prediction...
# '6feb05de-b54f-4f9d-a142-4e5cecb2a8f8'

# %%
napi.get_leaderboard(round_num=99)
# Out:
# 2018-03-24 15:41:06,844 INFO numerapi.numerapi: getting leaderboard for round 99
# [{'concordance': {'pending': False, 'value': True},
#   'consistency': 83.33333333333334,
#   'liveLogloss': None,
#   'originality': {'pending': False, 'value': True},
#   'paymentGeneral': None,
#   'paymentStaking': None,
#   'submissionId': '4459d3df-0a4b-4996-ad44-41abb7c45336',
#   'totalPayments': {'nmrAmount': Decimal('163.05'),
#    'usdAmount': Decimal('40.75')},
#   'username': 'ci_wp',
#   'validationLogloss': 0.692269984475575},
#  {'concordance': {'pending': False, 'value': True},
#   'consistency': 66.66666666666666,
#   'liveLogloss': None,
#   'originality': {'pending': False, 'value': False},
#   'paymentGeneral': None,
#   'paymentStaking': None,
#   'submissionId': '5c95e186-5703-4d71-9c92-d44122a98f18',
#   'totalPayments': {'nmrAmount': None, 'usdAmount': None},
#   'username': 'wcarroll',
#   'validationLogloss': 0.69251116060728},
# ...

# %% [markdown]
# you can generate api keys for various scopes;
# Upload submissions.
# Make stakes.
# Withdraw NMR
# Withdraw USD (via ETH)
# View historical submission info.
# View user info, (e.g. balance, withdrawal history)
